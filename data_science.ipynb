# %% [markdown]
# <a href="https://colab.research.google.com/github/DrR7data/data-science-porfolio/blob/main/data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ingest

# %%
import pandas as pd
df = range(1,15,2)
df1 = range(1,15,3)
for d in df:
  print(d)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13

# %% [markdown]
# # EDA

# %% [markdown]
# # Modeling

# %% [markdown]
# # Conclusion
